# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
df = pd.read_csv("/content/cleaned_training_dataset.csv")

df.head()
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                 1                              0.766127   45
# 1                 0                              0.957151   40
# 2                 0                              0.658180   38
# 3                 0                              0.233810   30
# 4                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                   2.0   0.802982         9120.0
# 1                                   0.0   0.121876         2600.0
# 2                                   1.0   0.085113         3042.0
# 3                                   0.0   0.036050         3300.0
# 4                                   1.0   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                               13                      0.0
# 1                                4                      0.0
# ...

# %%
df.shape
# Out:
# (120823, 12)

# %%
df.columns
# Out:
# Index(['SeriousDlqin2yrs', 'RevolvingUtilizationOfUnsecuredLines', 'age',
#        'NumberOfTime30-59DaysPastDueNotWorse', 'DebtRatio', 'MonthlyIncome',
#        'NumberOfOpenCreditLinesAndLoans', 'NumberOfTimes90DaysLate',
#        'NumberRealEstateLoansOrLines', 'NumberOfTime60-89DaysPastDueNotWorse',
#        'NumberOfDependents', 'TotalPastDue'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120823 entries, 0 to 120822
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   SeriousDlqin2yrs                      120823 non-null  int64
#  1   RevolvingUtilizationOfUnsecuredLines  120823 non-null  float64
#  2   age                                   120823 non-null  int64
#  3   NumberOfTime30-59DaysPastDueNotWorse  120823 non-null  float64
#  4   DebtRatio                             120823 non-null  float64
#  5   MonthlyIncome                         120823 non-null  float64
#  6   NumberOfOpenCreditLinesAndLoans       120823 non-null  int64
#  7   NumberOfTimes90DaysLate               120823 non-null  float64
#  8   NumberRealEstateLoansOrLines          120823 non-null  int64
#  9   NumberOfTime60-89DaysPastDueNotWorse  120823 non-null  float64
# ...

# %%
df.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     120823.000000                         120823.000000  120823.000000
# mean           0.069465                              0.332902      51.576471
# std            0.254245                              0.362298      14.682431
# min            0.000000                              0.000000      21.000000
# 25%            0.000000                              0.032309      41.000000
# 50%            0.000000                              0.172925      51.000000
# 75%            0.000000                              0.580341      62.000000
# max            1.000000                              4.937063     105.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                         120823.000000  120823.000000   1.208230e+05
# mean                               0.257136       0.409554   6.752099e+03
# ...

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="SeriousDlqin2yrs", data=df)

plt.title("Loan Default Distribution")
plt.xlabel("Default within 2 Years")
plt.ylabel("Number of Borrowers")

plt.show()

# %%
default_rate = df["SeriousDlqin2yrs"].value_counts(normalize=True) * 100
print(default_rate)
# Out:
# SeriousDlqin2yrs
# 0    93.053475
# 1     6.946525
# Name: proportion, dtype: float64

# %%
corr = df.corr()

plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, cmap="coolwarm")

plt.title("Feature Correlation Matrix")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x="SeriousDlqin2yrs", y="age", data=df)

plt.title("Age vs Loan Default")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x="SeriousDlqin2yrs", y="DebtRatio", data=df)

plt.title("Debt Ratio vs Loan Default")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x="SeriousDlqin2yrs", y="MonthlyIncome", data=df)

plt.title("Income vs Loan Default")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["RevolvingUtilizationOfUnsecuredLines"], bins=50)

plt.title("Credit Utilization Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x="SeriousDlqin2yrs", y="TotalPastDue", data=df)

plt.title("Late Payment History vs Default")

plt.show()

# %%
target_corr = df.corr()["SeriousDlqin2yrs"].sort_values(ascending=False)

print(target_corr)
# Out:
# SeriousDlqin2yrs                        1.000000
# TotalPastDue                            0.382010
# NumberOfTimes90DaysLate                 0.303723
# RevolvingUtilizationOfUnsecuredLines    0.275596
# NumberOfTime30-59DaysPastDueNotWorse    0.269563
# NumberOfTime60-89DaysPastDueNotWorse    0.259739
# NumberOfDependents                      0.048330
# DebtRatio                               0.023490
# NumberRealEstateLoansOrLines           -0.002134
# MonthlyIncome                          -0.020444
# NumberOfOpenCreditLinesAndLoans        -0.027950
# age                                    -0.107750
# Name: SeriousDlqin2yrs, dtype: float64

# %%
X = df.drop("SeriousDlqin2yrs", axis=1)
y = df["SeriousDlqin2yrs"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)
print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (96658, 11)
# X_test: (24165, 11)
# y_train: (96658,)
# y_test: (24165,)

# %%
X_train.to_csv("X_train.csv", index=False)
X_test.to_csv("X_test.csv", index=False)
y_train.to_csv("y_train.csv", index=False)
y_test.to_csv("y_test.csv", index=False)
